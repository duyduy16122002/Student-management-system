# %%
class student:
    mssv = 123456
    name = 'ABC'
    birth = '16/12/2002'
    class_stu = 'HQ8'
    
    def __init__(self, mssv, name, birth, class_stu):
        self.mssv = mssv
        self.name = name
        self.birth = birth
        self.class_stu = class_stu
    
    def accept(self,mssv,name,birth,class_stu):
        ob = student(mssv, name, birth, class_stu)
        ls.append(ob)
    
    def display(self, ob):
        print("Mã số sinh viên:", ob.mssv)
        print("Họ và tên:", ob.name)
        print("Ngày sinh:", ob.birth)
        print("Lớp:", ob.class_stu)
        print("\n")
    
    def search(self, id_sv):
        for i in range(len(ls)):
            if(ls[i].mssv == id_sv):
                return i
    def delete(self, id_sv):
        i = self.search(id_sv)
        del ls[i]
    
    def update(self, id_sv, new_id):
        i = obj.search(id_sv)
        ls[i].mssv = new_id

ls = []
obj = student(123,'abc','12','hqq')
print("\nStudent management, ")
print("\n1.Accept Student details\n2.Display Student Details\n3.Search Details of a Student\n4.Delete Details of Student\n5.Update Student Details\n6.Exit")
ch = 0
cont = 1
while ch !=6 :
    ch = int(input("Enter choice:"))
    if(ch == 1):
        while cont == 1:
            mssv = int(input('MSSV: '))
            name = input('Họ tên: ')
            birth = input('Ngày sinh: ')
            class_stu = input('Lớp: ')
            obj.accept(mssv,name,birth,class_stu)
            cont = int(input("0-End , 1-Continue: "))
    elif(ch == 2):
        print("\n")
        print("\nList of Students\n")
        for i in range(ls.__len__()):
            obj.display(ls[i])
    elif(ch == 3):
        print("\n Student Found, ")
        find_mssv = int(input('MSSV : '))
        s = obj.search(find_mssv)
        obj.display(ls[s])
    elif(ch == 4):
        del_id = int(input('MSSV: '))
        obj.delete(del_id)
        print(ls.__len__())
        print("List after deletion")
        for i in range(ls.__len__()):
            obj.display(ls[i])
    elif(ch == 5):
        old_id = int(input('MSSV cũ: '))
        new_id = int(input('MSSV mới: '))
        obj.update(old_id, new_id)
        print(ls.__len__())
        print("List after updation")
        for i in range(ls.__len__()):
            obj.display(ls[i])
    else:
        print("Thank You !")
# Out:
# Student management,
#
# 1.Accept Student details
# 2.Display Student Details
# 3.Search Details of a Student
# 4.Delete Details of Student
# 5.Update Student Details
# 6.Exit
# Enter choice:1
# MSSV: 22
# Họ tên: 55
# Ngày sinh: 4
# Lớp:
# 0-End , 1-Continue: 0
# Enter choice:5
# MSSV cũ: 22
# MSSV mới: 33
# 1
# List after updation
# Mã số sinh viên: 33
# Họ và tên: 55
# Ngày sinh: 4
# Lớp:
#
#
# Enter choice:6
# Thank You !
